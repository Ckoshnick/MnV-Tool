# %%
## Options
import pandas as pd
from PI_client import pi_client
pi = pi_client()
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 500)

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Local Data Loading

# %%
# filePath = 'data/OATtest.xlsx'
filePath = 'data/arc2yeardata.xlsx'
data = pd.read_excel(filePath, header=0, index_col=0, parse_date=True)
print(data.columns)
# Out:
# Index([u'chw', u'elec', u'steam'], dtype='object')

# %% [markdown]
# ### PI Data Loading

# %%
tags = pi.search_by_point('*shields*kbtu*')[0]
#tags += pi.search_by_point('*shields*kbtu*')[0]

print(tags)
# Out:
# [u'Shields_ChilledWater_Demand_kBtu', u'Shields_Electricity_Demand_kBtu', u'Shields_Steam_Demand_kBtu']

# %% [markdown]
# #### Pull tags

# %%
startDate = '2017-01-01'
endDate = '2018-01-01'
interval = '1 hour' #Can be "minute" "hour" "day"
calculation = 'calculated' # Redundant?

# data = pi.get_stream_by_point(tags, start=startDate, end=endDate, interval=interval, calculation=calculation)

# %%
## Imports

## Mac imports
# import sys
# toolPath = r'/Users/decolvin/Box Sync/UCD_ECO_coding/mypy'
# sys.path.append(toolPath)

## Main Imports
import mnv13 as mnv
print(mnv.version)
import matplotlib.pyplot as plt
print("Success!")
# Out:
# Version 1.3
# Success!

# %% [markdown]
# # Data Section

# %%
inputDict = {'IQRmult' : 4.0,
             'IQR' : 'y', 
             'resampleRate' : 'D', #'D' for daily 'H' for hourly
             'verbosity' : 3,
             'sliceType' : 'ranges', #half, middate, ranges
             'midDate' : '2017-01-01', #only needed with sliceType : 'middate'
             'dateRanges' : ['2015-01-01','2017-07-15','2017-08-15','2018-04-01'], #only needed with sliceType : 'ranges'
             'OATsource' : 'file', #'self' or 'file'
             'OATname' : 'OAT', #Name of OAT column if OATsource is 'self'} #only needed with sliceType : 'ranges'
            }

dc = mnv.data_handler(data[data.columns[0]], inputDict)
dc.default_clean()

## Run the next line incase the y-range is FUBAR
dc._outlier_plot(dc.modifiedData[dc.com], yrange=(-100,dc.modifiedData[dc.com].max()*1.1)) 

# plot 3
dc._pre_post_plot()
# Out:
# Q(75%): 98.31 Q(25%): 0.13
# IQR value is 98.19
# Ceiling adjusted by IQR - Now 491.06
# Deprecation warning: this function should be called calculate_degree_hours(). Use that name instead
# OAT being loaded from master file

# %% [markdown]
# # Many Linear Models

# %%
modelDict = {'params': 'CDH + HDH + C(month) + C(weekend)',
             'testTrainSplit': 'random',
             'randomState': None,
             'testSize': 0.2,
             'commodityRate': 0.056,
             'paramList': ['','C(weekday)']}

allmod = mnv.many_ols(dc.pre, dc.post, modelDict)

allmod.run_all_linear()
print(allmod.statsPool[0:5])
allmod.plot_pool(5)
modelDict['params'] = allmod.statsPool.iloc[0]['params']
# Out:
#         AIC       AR2        R2    cvrmse postDiff                   params                                            summary
# 5   6791.95  0.904587  0.905226  0.335545 -49165.9  CDH + HDH2 + C(weekday)                              OLS Regression Res...
# 9   6807.96  0.896549  0.897241  0.341581 -52466.8   CDH + HDH + C(weekday)                              OLS Regression Res...
# 12  6873.81  0.878873  0.879414  0.367973 -52957.6                CDH + HDH                              OLS Regression Res...
# 13  6899.64  0.885492  0.886003  0.378714 -45985.8         CDH + C(weekday)                              OLS Regression Res...
# 7    6927.2  0.872531  0.872815  0.390949 -48627.6                      CDH                              OLS Regression Res...

# %% [markdown]
# # Single Linear Model

# %%
mod = mnv.ols_model(dc.pre, dc.post, modelDict)
mod.model_plot()


plt.show() # Show plot before Stats summary
print(mod.vif)
mod.Fit.summary()
# Out:
#                   VIF
# const       11.818835
# HDH          1.943361
# CDH          1.941766
# dayofmonth   1.002811
# dayofweek    1.003219
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    chw   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1406.
# Date:                Mon, 25 Jun 2018   Prob (F-statistic):          2.46e-193
# Time:                        10:05:04   Log-Likelihood:                -3471.9
# No. Observations:                 449   AIC:                             6950.
# Df Residuals:                     446   BIC:                             6962.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    446.1183     68.651      6.498      0.000     311.199     581.037
# CDH            9.9269      0.285     34.789      0.000       9.366      10.488
# HDH           -1.2103      0.265     -4.565      0.000      -1.731      -0.689
# ==============================================================================
# Omnibus:                      405.987   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9490.622
# Skew:                          -3.961   Prob(JB):                         0.00
# Kurtosis:                      24.084   Cond. No.                         535.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
mod.kfold()
print(mod.kfoldStats)
print('')
print(mod.kfoldRelative.round(1))
# Out:
# (0.2, 'nfolds', 5)
#          R2       AR2            mse
# 1  0.892601  0.892120  248565.871305
# 2  0.884698  0.884182  257021.045468
# 3  0.890618  0.890129  259736.190758
# 4  0.882468  0.881942  263079.431071
# 0  0.868888  0.868300  294900.754681
#
# 1          93.9
# 2          97.1
# 3          98.1
# 4          99.4
# 0         111.4
# mse    264661.0
# dtype: float64

# %% [markdown]
# ### Savings

# %%
#rates = {'chw':0.056, 'steam':0.0157, 'elec':0.030} #kBTU prices for 2016(?)
#commodity = 'chw'

print("Savings = $" +str(round(mod.postCumsum * mod.params.commodityRate,2)))
mod.savings_plot(yaxis='dollars')
# Out:
# Savings = $-3149.91
