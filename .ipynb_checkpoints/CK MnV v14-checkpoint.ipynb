# %%
import sys

import pandas as pd
import matplotlib.pyplot as plt

from IPython.core.display import display, HTML

# toolPath = r'/Users/decolvin/Box Sync/UCD_ECO_coding/mypy'
# sys.path.append(toolPath)

import mnv14 as mnv

display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 500)

print(mnv.version)
# Out:
# <style>.container { width:90% !important; }</style>
# Version 1.4

# %% [markdown]
# ### Local Data Loading

# %%
filePath = 'data/gbsfkilledvif.xlsx'
data = pd.read_excel(filePath, header=0, index_col=0, parse_date=True, infer_datetime_format=True)
print(data.columns)
# Out:
# Index(['chw', 'steam', 'ele', 'OAT'], dtype='object')

# %% [markdown]
# ### PI Data Loading

# %%
from PI_client import pi_client
pi = pi_client()

tags = pi.search_by_point('*shields*kbtu*')[0]
#tags += pi.search_by_point('*shields*kbtu*')[0]

print(tags)
# Out:
# ['Shields_ChilledWater_Demand_kBtu', 'Shields_Electricity_Demand_kBtu', 'Shields_Steam_Demand_kBtu']

# %% [markdown]
# #### Pull tags

# %%
startDate = '2017-01-01'
endDate = '2018-01-01'
interval = '1 hour' #Can be "minute" "hour" "day"
calculation = 'calculated' # Redundant?

# data = pi.get_stream_by_point(tags, start=startDate, end=endDate, interval=interval, calculation=calculation)

# %% [markdown]
# # Data Section

# %%
dataParams = {'column': 1,
              'IQRmult' : 4.0,
              'IQR' : 'y', 
              'resampleRate' : 'D', #'D' for daily 'H' for hourly
              'OATsource' : 'file', #'self' or 'file'
              'OATname' : 'OAT', #Name of OAT column if OATsource is 'self'} #only needed with sliceType : 'ranges'
              'sliceType' : 'ranges', #half, middate, ranges
              'midDate' : '2017-01-01', #only needed with sliceType : 'middate'
              'dateRanges' : ['2016-06-01','2017-06-01','2017-08-01','2017-12-01'], #only needed with sliceType : 'ranges'
             }

dk = mnv.data_keeper(data, dataParams)
dk.default_clean()

# Plots
dk._outlier_plot()
dk._resampled_plot(yrange=(-100,dk.modifiedData[dk.com].max()*1.1))
dk._pre_post_plot()
# Out:
# Q(75%): 3638.23 Q(25%): 2292.69
# IQR value is 1345.54
# IQRupper 9020.38 IQRlower -3089.46
# Ceiling adjusted by IQR - Now 9020.38
# OAT being loaded from master file

# %%
dk.modifiedData
# Out:
#                    steam         HDH         CDH           HDH2           CDH2  year month  dayofmonth  hour  minute  dayofweek  weekofyear  daytime  weekday  saturday  sunday
# DateTime
# 2015-01-01      0.000000  528.357775    0.000000  279161.938324       0.000000  2015     1           1     0       0          3           1        0        1         0       0
# 2015-01-02      0.000000  531.266016    0.000000  282243.580118       0.000000  2015     1           2     0       0          4           1        0        1         0       0
# 2015-01-03      0.000000  502.985312    0.000000  252994.223817       0.000000  2015     1           3     0       0          5           1        0        0         1       0
# 2015-01-04      0.000000  444.533314    0.000000  197609.867381       0.000000  2015     1           4     0       0          6           1        0        0         0       1
# 2015-01-05      0.000000  407.186295    0.000000  165800.678539       0.000000  2015     1           5     0       0          0           2        0        1         0       0
# 2015-01-06      0.000000  330.187970    0.000000  109024.095755       0.000000  2015     1           6     0       0          1           2        0        1         0       0
# 2018-05-27  68139.660000   42.326103  228.127045    1791.498977   52041.948692  2018     5          27     0       0          6          21        0        0         0       1
# 2018-05-28  67227.516410    6.310588  330.692039      39.823518  109357.224538  2018     5          28     0       0          0          22        0        1         0       0
# 2018-05-29  69926.770874    0.000000  354.463175       0.000000  125644.142231  2018     5          29     0       0          1          22        0        1         0       0
# 2018-05-30  75640.910243   52.864580   87.216425    2794.663868    7606.704873  2018     5          30     0       0          2          22        0        1         0       0
# 2018-05-31  76920.298047  106.857625   48.857019   11418.552033    2387.008297  2018     5          31     0       0          3          22        0        1         0       0
# 2018-06-01  76987.955390   83.421266  178.036508    6959.107577   31696.998226  2018     6           1     0       0          4          22        0        1         0       0
# 2018-06-02  66588.588345   22.516131  319.461385     506.976167  102055.576782  2018     6           2     0       0          5          22        0        0         1       0
# 2018-06-03  64028.619108    1.931416  374.687012       3.730368  140390.356945  2018     6           3     0       0          6          22        0        0         0       1
# 2018-06-04  66841.882286   11.958157  278.214891     142.997530   77403.525429  2018     6           4     0       0          0          23        0        1         0       0
# 2018-06-05  66312.804297   48.383237  171.629260    2340.937588   29456.602898  2018     6           5     0       0          1          23        0        1         0       0
# 2018-06-06  66822.698747   50.049320  137.522626    2504.934404   18912.472566  2018     6           6     0       0          2          23        0        1         0       0
# 2018-06-07  66392.074161   60.263378  139.588748    3631.674732   19485.018657  2018     6           7     0       0          3          23        0        1         0       0
# 2018-06-08  65744.923701   52.072932  205.691634    2711.590256   42309.048353  2018     6           8     0       0          4          23        0        1         0       0
# 2018-06-09  60478.551575   18.364645  136.566304     337.260178   18650.355354  2018     6           9     0       0          5          23        0        0         1       0
# 2018-06-10  63716.509431   44.975728  144.091758    2022.816119   20762.434847  2018     6          10     0       0          6          23        0        0         0       1
# 2018-06-11  65189.340806   41.214192  249.881257    1698.609601   62440.642687  2018     6          11     0       0          0          24        0        1         0       0
# 2018-06-12  59006.250907    6.427112  363.169368      41.307766  131891.989701  2018     6          12     0       0          1          24        0        1         0       0
# 2018-06-13  19783.202222   12.539367  310.602913     157.235736   96474.169858  2018     6          13     0       0          2          24        0        1         0       0
#
# [1260 rows x 16 columns]

# %% [markdown]
# # Many Linear Models

# %%
modelParams = {'params': ['CDH','HDH','month','hour','weekday'],
               'testTrainSplit': 'random',
               'randomState': None,
               'testSize': 0.2,
               'commodityRate': 0.0157,
               'paramPermuteList': ['', 'C(weekday)', 'C(month)']}

allmod = mnv.many_ols(dk.pre, dk.post, modelParams)

allmod.run_all_linear()
print(allmod.statsPool[0:5])
allmod.plot_pool(1)
modelParams['params'] = allmod.statsPool.iloc[0]['params']
# Out:
#         AIC       AR2        R2     cvrmse     postDiff                               params                                            summary
# 6   5764.87  0.970413  0.971735  0.0638485  -1.7186e+06                CDH + HDH2 + C(month)                              OLS Regression Res...
# 19  5775.18  0.968928  0.970423   0.064827 -1.74399e+06  CDH2 + HDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 18  5788.76  0.964319  0.965913  0.0673959 -1.71551e+06               CDH2 + HDH2 + C(month)                              OLS Regression Res...
# 7   5790.22  0.967832   0.96938  0.0667133 -1.68872e+06   CDH + HDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 2   5802.38  0.965621  0.967157  0.0681479 -1.67972e+06                 CDH + HDH + C(month)                              OLS Regression Res...

# %% [markdown]
# # Single Linear Model

# %%
mod = mnv.ols_model(dk.pre, dk.post, modelParams)


mod.model_plot()
mod.calculate_kfold()
mod.calculate_vif()

print(mod.vif[mod.vif['VIF'] > 10])

print('\nKfold')
print(mod.kfoldStats)
print(mod.kfoldRelative)

plt.show() # Show plot before Stats summary
mod.Fit.summary()
# Out:
#              VIF
# const  33.247863
#
# Kfold
#          R2       AR2           mse
# 1  0.971910  0.970495  2.074710e+07
# 3  0.969095  0.967539  2.254047e+07
# 4  0.968692  0.967116  2.293215e+07
# 2  0.966171  0.964467  2.327682e+07
# 0  0.965583  0.963844  2.402495e+07
# 1        9.137960e+01
# 3        9.927843e+01
# 4        1.010036e+02
# 2        1.025217e+02
# 0        1.058167e+02
# <mse>    2.270430e+07
# Name: rel. pct., dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  steam   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     555.1
# Date:                Wed, 01 Aug 2018   Prob (F-statistic):          2.03e-193
# Time:                        16:09:18   Log-Likelihood:                -2887.8
# No. Observations:                 292   AIC:                             5806.
# Df Residuals:                     277   BIC:                             5861.
# Df Model:                          14
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        6.311e+04   1800.700     35.046      0.000    5.96e+04    6.67e+04
# C(weekday)[T.1]  1710.3730    641.125      2.668      0.008     448.276    2972.470
# C(month)[T.2]    1928.3022   1656.817      1.164      0.245   -1333.250    5189.854
# C(month)[T.3]    6429.9951   1841.241      3.492      0.001    2805.392    1.01e+04
# C(month)[T.4]    9652.1212   1881.516      5.130      0.000    5948.234    1.34e+04
# C(month)[T.5]    1340.9024   2006.154      0.668      0.504   -2608.343    5290.148
# C(month)[T.6]   -1.109e+04   2101.025     -5.277      0.000   -1.52e+04   -6950.731
# C(month)[T.7]   -1.241e+04   2111.420     -5.876      0.000   -1.66e+04   -8249.635
# C(month)[T.8]   -1.237e+04   2081.167     -5.943      0.000   -1.65e+04   -8271.955
# C(month)[T.9]   -1.691e+04   2000.796     -8.453      0.000   -2.09e+04    -1.3e+04
# C(month)[T.10]  -1.007e+04   1942.107     -5.186      0.000   -1.39e+04   -6247.933
# C(month)[T.11]  -2761.6557   1765.707     -1.564      0.119   -6237.565     714.254
# C(month)[T.12]  -1051.4674   1499.888     -0.701      0.484   -4004.095    1901.160
# CDH2               -0.0702      0.010     -6.977      0.000      -0.090      -0.050
# HDH2                0.2963      0.008     37.544      0.000       0.281       0.312
# ==============================================================================
# Omnibus:                       26.195   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.752
# Skew:                          -0.427   Prob(JB):                     6.42e-14
# Kurtosis:                       5.065   Cond. No.                     1.54e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Savings

# %%
print("Savings = $" +str(round(mod.postCumsum * mod.params.commodityRate,1)))
mod.savings_plot(yaxis='dollars')
# Out:
# Savings = $-96690.6

# %%
mnv.create_archive(dk, mod)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:87: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
# Out:
# testHey
# 'Hey'
