# %%
## Options
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 500)

# %load_ext autoreload
# %autoreload 2

## Data Loading
filePath = 'data/arc2yeardata.xlsx'
data = pd.read_excel(filePath, header=0, index_col=0, parse_date=True)
print(data.columns)
# Out:
# <style>.container { width:90% !important; }</style>
# Index([u'chw', u'elec', u'steam'], dtype='object')

# %%
## Imports

## Mac imports
import sys
toolPath = r'/Users/decolvin/Box Sync/UCD_ECO_coding/mypy'
sys.path.append(toolPath)

## Main Imports
import mnv12 as mnv
print(mnv.version)
import matplotlib.pyplot as plt
print("Success!")
# Out:
# Version 1.2
# Success!

# %% [markdown]
# # Data Section

# %%
inputDict = {'IQRmult' : 4.0,
                 'IQR' : 'y',
                 'resampleRate' : 'D',
                 'verbosity' : 3,
                 'sliceType' : 'ranges', #half, middate, ranges
                 'midDate' : '2017-01-01', #only needed with sliceType : 'middate'
                 'dateRanges' : ['2015-01-01','2017-07-15','2017-08-15','2018-04-01'],
                 'OATname' : None,
                 'OATsource' : 'file'} #only needed with sliceType : 'ranges'}

dc = mnv.data_handler(data[data.columns[1]], inputDict)
dc.default_clean()


## Run the next line incase the y-range is FUBAR
dc._outlier_plot(dc.modifiedData[dc.com], yrange=(-100,dc.modifiedData[dc.com].max()*1.1)) 
plt.show()

#Show splitting
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(dc.pre[dc.com],color='b')
ax.plot(dc.post[dc.com],color='g')
plt.show()
# Out:
# Q(75%): 258.82 Q(25%): 207.29
# IQR value is 51.53
# Ceiling adjusted by IQR - Now 464.96
# Floor adjusted by IQR   - Now 1.15

# %% [markdown]
# # Many Linear Models

# %%
modelDict = {'params': 'CDH + HDH + C(month) + C(weekend)',
             'testTrainSplit': 'random',
             'randomState': 4291990,
             'testSize': 0.2,
             'commodityRate': 0.056,
             'paramList': ['','C(month)','C(weekend)']}

allmod = mnv.many_ols(dc.pre, dc.post, modelDict)

allmod.run_all_linear()
print(allmod.statsPool[0:5])
allmod.plot_pool(5)
modelDict['params'] = allmod.statsPool.iloc[0]['params']
# Out:
# Could not complete model with CDH + HDH
# No objects to concatenate
# Could not complete model with CDH + HDH2
# No objects to concatenate
# Could not complete model with CDH
# No objects to concatenate
# Could not complete model with CDH2 + HDH
# No objects to concatenate
# Could not complete model with CDH2 + HDH2
# No objects to concatenate
# Could not complete model with CDH2
# No objects to concatenate
# Could not complete model with HDH
# No objects to concatenate
# Could not complete model with HDH2
# No objects to concatenate
#         AIC       AR2        R2     cvrmse postDiff                              params                                            summary
# 9   1558.17  0.610348  0.659493  0.0423697   109509   CDH + HDH + C(month) + C(weekend)                              OLS Regression Res...
# 19   1558.7  0.605533  0.651732  0.0426307   111565        CDH2 + C(month) + C(weekend)                              OLS Regression Res...
# 20  1558.93  0.604703  0.650999  0.0426755   110624         CDH + C(month) + C(weekend)                              OLS Regression Res...
# 26  1559.07  0.607213  0.656754  0.0425398   110697  CDH2 + HDH + C(month) + C(weekend)                              OLS Regression Res...
# 24  1559.43  0.605962  0.655661  0.0426074   109361  CDH + HDH2 + C(month) + C(weekend)                              OLS Regression Res...

# %% [markdown]
# # Single Linear Model

# %%
mod = mnv.ols_model(dc.pre, dc.post, modelDict)
mod.model_plot()


plt.show() # Show plot before Stats summary
print(mod.vif)
mod.Fit.summary()
# Out:
#                  VIF
# const      78.601123
# HDH        58.975019
# CDH        39.371093
# HDH2       34.577681
# CDH2       19.798644
# month_2     1.706984
# month_3     2.811232
# month_4     2.114878
# month_5     4.215303
# month_6     3.762951
# month_7     4.677336
# month_8     3.919813
# month_9     2.980058
# month_10    1.994768
# month_11    1.626380
# month_12    1.374626
# weekend_1   1.124306
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   elec   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     13.42
# Date:                Tue, 12 Jun 2018   Prob (F-statistic):           4.88e-17
# Time:                        10:32:54   Log-Likelihood:                -764.09
# No. Observations:                 112   AIC:                             1558.
# Df Residuals:                      97   BIC:                             1599.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         5817.8011    140.425     41.430      0.000    5539.097    6096.505
# C(month)[T.2L]     -78.1573    108.271     -0.722      0.472    -293.045     136.731
# C(month)[T.3L]    -248.3571    110.819     -2.241      0.027    -468.302     -28.412
# C(month)[T.4L]      -0.4380    133.180     -0.003      0.997    -264.764     263.888
# C(month)[T.5L]     -82.3764    136.163     -0.605      0.547    -352.622     187.869
# C(month)[T.6L]    -231.7836    145.120     -1.597      0.113    -519.807      56.240
# C(month)[T.7L]    -373.7516    172.819     -2.163      0.033    -716.749     -30.754
# C(month)[T.8L]    -315.4531    156.592     -2.014      0.047    -626.245      -4.661
# C(month)[T.9L]    -436.3939    159.478     -2.736      0.007    -752.913    -119.875
# C(month)[T.10L]    -20.1282    151.471     -0.133      0.895    -320.757     280.500
# C(month)[T.11L]   -286.5512    127.591     -2.246      0.027    -539.785     -33.318
# C(month)[T.12L]   -419.6964    108.321     -3.875      0.000    -634.684    -204.709
# C(weekend)[T.1L]  -556.0118     49.256    -11.288      0.000    -653.771    -458.252
# CDH                  1.0209      0.362      2.822      0.006       0.303       1.739
# HDH                  0.5578      0.359      1.556      0.123      -0.154       1.269
# ==============================================================================
# Omnibus:                       21.372   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.009
# Skew:                          -0.887   Prob(JB):                     6.80e-08
# Kurtosis:                       4.982   Cond. No.                     3.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Savings

# %%
#rates = {'chw':0.056, 'steam':0.0157, 'elec':0.030} #kBTU prices for 2016(?)
#commodity = 'chw'

print("Savings = $" +str(round(mod.postCumsum * mod.params.commodityRate,2)))
mod.savings_plot(yaxis='dollars')
# Out:
# Savings = $6132.49
