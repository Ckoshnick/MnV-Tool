# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 500)
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#filePath = 'data/arc2yeardata.xlsx'
filePath = '/Volumes/OM/ECO/M&V/Holiday Shutdowns/Memorial Day 2018/Archive/Campus Data 052918.csv'
#data = pd.read_excel(filePath, header=0, index_col=0, parse_date=True)
data = pd.read_csv(filePath, header=0, index_col=0, parse_dates=True)
print(data.columns)
# Out:
# Index([u'chw_tonh', u'steam_klb', u'OAT'], dtype='object')

# %%
# %load_ext autoreload
# %autoreload 2

import sys
toolPath = r'/Users/decolvin/Box Sync/UCD_ECO_coding/mypy'
sys.path.append(toolPath)

import mnv
import matplotlib.pyplot as plt
print("Success!")
# Out:
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Success!

# %%
data.head()
# Out:
#                         chw_tonh   steam_klb        OAT
# DateTime
# 2016-01-01 00:00:00  1099.289196  166.133731  40.409643
# 2016-01-01 01:00:00  1341.298794  168.051633  40.079128
# 2016-01-01 02:00:00   770.730609  166.059831  40.090998
# 2016-01-01 03:00:00   812.078312  170.856988  40.114107
# 2016-01-01 04:00:00   862.013005  177.357802  39.902123

# %%
inputDict = {'IQRmult' : 4.0,
                 'IQR' : 'y',
                 'ceiling' : 50000,
                 'floor' : 0,
                 'resampleRate' : 'D',
                 'verbosity' : 3,
                 'sliceType' : 'ranges', #half, middate, ranges
                 'midDate' : '2018-01-01', #only needed with sliceType : 'middate'
                 'dateRanges' : ['2017-01-01','2018-01-01','2016-01-01','2017-01-01'], #only needed with sliceType : 'ranges'
                 'OATname' : None,
                 'OATsource' : 'file'} #only needed with sliceType : 'ranges'}

dc = mnv.data_handler(data[data.columns[0]], inputDict)
dc.default_clean()

# Run this incase the y-range is FUBAR
#dc.outlier_plot(dc.modifiedData[dc.com])
# Out:
# Q(75%): 5671.15 Q(25%): 1437.99
# IQR value is 4233.16
# Ceiling adjusted by IQR - Now 22603.79
# 0

# %%
fig = plt.figure(figsize=(18,5))
ax = fig.add_subplot(111)
ax.plot(dc.pre[dc.com],color='b')
ax.plot(dc.post[dc.com],color='g')
plt.show()

# %%
dc.pre.columns
# Out:
# Index([u'chw_tonh', u'HDH', u'CDH', u'HDH2', u'CDH2', u'year', u'month', u'day', u'hour', u'minute', u'weekday', u'daytime', u'weekend', u'saturday', u'sunday'], dtype='object')

# %%
allmod = mnv.many_ols(dc.pre, dc.post, inputParams=['', 'C(month)', 'C(hour)','C(weekend)','C(daytime)'])

allmod.run_all_linear()
print(allmod.statsPool[0:5])
#allmod.plot_pool(2)
topParams = allmod.statsPool.iloc[0]['params']
# Out:
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in divide
#   return self.params / self.bse
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/statsmodels/regression/linear_model.py:1396: RuntimeWarning: invalid value encountered in double_scalars
#   return self.ess/self.df_model
#         AIC       AR2      BIC        R2          mse                                             params                                                sum
# 0   5196.11  0.979735  5237.88  0.980668  1.40943e+08     CDH + HDH + C(month) + C(weekend) + C(daytime)                              OLS Regression Res...
# 38  5196.11  0.979735  5237.88  0.980668  1.40943e+08  CDH + HDH + C(month) + C(hour) + C(weekend) + ...                              OLS Regression Res...
# 32  5196.11  0.979735  5237.88  0.980668  1.40943e+08        CDH + HDH + C(month) + C(hour) + C(weekend)                              OLS Regression Res...
# 77  5196.11  0.979735  5237.88  0.980668  1.40943e+08                  CDH + HDH + C(month) + C(weekend)                              OLS Regression Res...
# 47  5218.94  0.977713  5260.71  0.978739  1.55009e+08       CDH + HDH2 + C(month) + C(hour) + C(weekend)                              OLS Regression Res...

# %%
params = topParams
mod = mnv.ols_model(dc.pre, dc.post, params)
mod.model_plot()
plt.show()
mod.Fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               chw_tonh   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1051.
# Date:                Wed, 06 Jun 2018   Prob (F-statistic):          1.52e-188
# Time:                        08:03:45   Log-Likelihood:                -2586.1
# No. Observations:                 240   AIC:                             5196.
# Df Residuals:                     228   BIC:                             5238.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        6.261e+04   5540.314     11.300      0.000    5.17e+04    7.35e+04
# C(month)[T.2]   -3655.9787   3631.079     -1.007      0.315   -1.08e+04    3498.783
# C(month)[T.3]   -4032.3386   4209.496     -0.958      0.339   -1.23e+04    4262.150
# C(month)[T.4]   -1879.6293   4547.971     -0.413      0.680   -1.08e+04    7081.799
# C(month)[T.5]    6301.1937   5074.683      1.242      0.216   -3698.080    1.63e+04
# C(month)[T.6]    1.366e+04   5427.616      2.517      0.013    2964.181    2.44e+04
# C(month)[T.7]     1.17e+04   5654.307      2.069      0.040     556.545    2.28e+04
# C(month)[T.8]    2.585e+04   5591.898      4.624      0.000    1.48e+04    3.69e+04
# C(month)[T.9]    -1.62e+04   1.34e+04     -1.207      0.229   -4.26e+04    1.02e+04
# C(month)[T.10]   1.254e-12   1.15e-12      1.092      0.276   -1.01e-12    3.52e-12
# C(month)[T.11]  -5.101e-14   6.71e-14     -0.760      0.448   -1.83e-13    8.13e-14
# C(month)[T.12]   1.428e-12   3.58e-13      3.991      0.000    7.23e-13    2.13e-12
# C(weekend)[T.1] -8897.7426   1719.619     -5.174      0.000   -1.23e+04   -5509.366
# CDH               424.7802      9.535     44.549      0.000     405.992     443.568
# HDH               -89.1943     13.299     -6.707      0.000    -115.399     -62.990
# ==============================================================================
# Omnibus:                      107.902   Durbin-Watson:                   1.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1044.039
# Skew:                          -1.493   Prob(JB):                    1.95e-227
# Kurtosis:                      12.772   Cond. No.                     2.31e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.04e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
rates = {'chw':0.047, 'steam':0.0157, 'elec':0.065} #kBTU prices for 2016(?)
commodity = 'chw'

mod.savings_plot(yaxis='dollars', rate=rates[commodity])
print(mod.postCumsum * rates[commodity])
# Out:
# /Users/decolvin/anaconda/envs/MnV_Stuff/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# 46206.7842703
