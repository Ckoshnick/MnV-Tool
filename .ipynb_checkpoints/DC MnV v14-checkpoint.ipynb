# %%
## Options
import pandas as pd
from PI_client import pi_client
pi = pi_client()
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 500)

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Local Data Loading

# %%
# filePath = 'data/OATtest.xlsx'
filePath = 'data/gbsfkilledvif.xlsx'
data = pd.read_excel(filePath, header=0, index_col=0, parse_date=True)
print(data.columns)
# Out:
# Index([u'chw', u'steam', u'ele', u'OAT'], dtype='object')

# %% [markdown]
# ### PI Data Loading

# %%
tags = pi.search_by_point('*shields*kbtu*')[0]
#tags += pi.search_by_point('*shields*kbtu*')[0]

print(tags)
# Out:
# [u'Shields_ChilledWater_Demand_kBtu', u'Shields_Electricity_Demand_kBtu', u'Shields_Steam_Demand_kBtu']

# %% [markdown]
# #### Pull tags

# %%
startDate = '2017-01-01'
endDate = '2018-01-01'
interval = '1 hour' #Can be "minute" "hour" "day"
calculation = 'calculated' # Redundant?

# data = pi.get_stream_by_point(tags, start=startDate, end=endDate, interval=interval, calculation=calculation)

# %%
## Imports

## Mac imports
# import sys
# toolPath = r'/Users/decolvin/Box Sync/UCD_ECO_coding/mypy'
# sys.path.append(toolPath)

## Main Imports
import mnv14 as mnv
print(mnv.version)
import matplotlib.pyplot as plt
print("Success!")
# Out:
# Version 1.4
# Success!

# %% [markdown]
# # Data Section

# %%
inputDict = {'IQRmult' : 4.0,
             'IQR' : 'y', 
             'resampleRate' : 'D', #'D' for daily 'H' for hourly
             'verbosity' : 3,
             'sliceType' : 'ranges', #half, middate, ranges
             'midDate' : '2017-01-01', #only needed with sliceType : 'middate'
             'dateRanges' : ['2016-06-01','2017-06-01','2017-08-01','2017-12-01'], #only needed with sliceType : 'ranges'
             'OATsource' : 'file', #'self' or 'file'
             'OATname' : 'OAT', #Name of OAT column if OATsource is 'self'} #only needed with sliceType : 'ranges'
            }

dc = mnv.data_handler(data[data.columns[2]], inputDict)
dc.default_clean()

## Run the next line incase the y-range is FUBAR
dc._outlier_plot(dc.modifiedData[dc.com], yrange=(-100,dc.modifiedData[dc.com].max()*1.1)) 

# plot 3
dc._pre_post_plot()
# Out:
# Q(75%): 903.41 Q(25%): 775.42
# IQR value is 127.99
# Ceiling adjusted by IQR - Now 1415.37
# Floor adjusted by IQR   - Now 263.47
# OAT being loaded from master file

# %% [markdown]
# # Many Linear Models

# %%
modelDict = {'params': ['CDH','HDH','month','hour','weekday'],
             'testTrainSplit': 'random',
             'randomState': None,
             'testSize': 0.2,
             'commodityRate': 0.056,
             'paramPermuteList': ['', 'C(hour)', 'C(weekday)', 'C(month)']}

allmod = mnv.many_ols(dc.pre, dc.post, modelDict)

allmod.run_all_linear()
print(allmod.statsPool[0:20])
allmod.plot_pool(1)
modelDict['params'] = allmod.statsPool.iloc[0]['params']
# Out:
# Could not calculate VIF for C(hour)
# Exception caught: Arrays cannot be empty
# Could not calculate VIF for C(hour)
# Exception caught: Arrays cannot be empty
#         AIC       AR2        R2     cvrmse postDiff                                         params                                            summary
# 5   4198.02  0.845411  0.852848  0.0156021  12114.3            CDH2 + HDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 9   4207.83  0.846376  0.853767  0.0158664  13448.5   CDH + HDH2 + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 17  4209.18  0.843128  0.850675  0.0159031  14169.5    CDH + HDH + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 64  4209.54  0.842959  0.850514   0.015913  13072.1             CDH + HDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 16  4216.32  0.838061  0.845295  0.0161249  11157.6                    HDH + C(weekday) + C(month)                              OLS Regression Res...
# 4   4220.08   0.83494  0.842881  0.0162026  15125.4   CDH2 + HDH + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 42  4227.54   0.82883  0.836477  0.0164376  5556.14                   HDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 44  4234.69  0.832723   0.84077  0.0166132  13293.3              CDH + HDH + C(weekday) + C(month)                              OLS Regression Res...
# 33  4236.52  0.834051  0.842034  0.0166654  10914.6             CDH2 + HDH + C(weekday) + C(month)                              OLS Regression Res...
# 51  4237.62  0.832096  0.840174  0.0166966  15695.4  CDH2 + HDH2 + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 62  4238.49  0.827868  0.835557  0.0167488  7511.92          HDH + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 41  4238.76  0.826118  0.833886  0.0167565  11541.1                    CDH + C(weekday) + C(month)                              OLS Regression Res...
# 24  4242.67  0.826867  0.834601   0.016869  7367.77         HDH2 + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 8   4251.91   0.82013  0.828166  0.0171382  13932.3                   CDH2 + C(weekday) + C(month)                              OLS Regression Res...
# 28  4263.27  0.816984  0.824531  0.0175034   9296.6                C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 38  4264.73  0.812714  0.821081  0.0175184  10873.5          CDH + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 10  4265.64   0.80055   0.80946   0.017546    14309         CDH2 + C(hour) + C(weekday) + C(month)                              OLS Regression Res...
# 31  4277.54  0.789632    0.7918  0.0182062  28856.2                       CDH2 + HDH2 + C(weekday)                              OLS Regression Res...
# 32  4281.62  0.783744   0.78523  0.0183649  27040.7                    HDH2 + C(hour) + C(weekday)                              OLS Regression Res...
# 56  4284.35   0.78441  0.785891  0.0184511  30597.6                               HDH + C(weekday)                              OLS Regression Res...

# %% [markdown]
# # Single Linear Model

# %%
mod = mnv.ols_model(dc.pre, dc.post, modelDict)
mod.model_plot()

mod.kfold()
mod.calculate_vif()

print(mod.vif[mod.vif['VIF'] > 10])

print('\nKfold')
print(mod.kfoldStats)
print(mod.kfoldRelative)

plt.show() # Show plot before Stats summary
mod.Fit.summary()
# Out:
#              VIF
# const  33.247863
#
# Kfold
#          R2       AR2            mse
# 2  0.860409  0.853379   96087.045888
# 0  0.848890  0.841253  100324.995624
# 3  0.844082  0.836230  103098.163506
# 4  0.847447  0.839765  107587.875577
# 1  0.826014  0.817252  115452.898519
# 2          91.940528
# 0          95.995594
# 3          98.649090
# 4         102.945054
# 1         110.470671
# mse    104510.000000
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ele   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     111.2
# Date:                Fri, 13 Jul 2018   Prob (F-statistic):          9.22e-105
# Time:                        16:33:07   Log-Likelihood:                -2088.0
# No. Observations:                 292   AIC:                             4206.
# Df Residuals:                     277   BIC:                             4261.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         1.893e+04    104.817    180.613      0.000    1.87e+04    1.91e+04
# C(weekday)[T.1L]  1401.2758     41.024     34.157      0.000    1320.517    1482.034
# C(month)[T.2L]     225.3574    103.313      2.181      0.030      21.980     428.735
# C(month)[T.3L]     534.3702    108.989      4.903      0.000     319.818     748.922
# C(month)[T.4L]     541.7218    111.933      4.840      0.000     321.375     762.068
# C(month)[T.5L]     280.5226    119.408      2.349      0.020      45.460     515.585
# C(month)[T.6L]      12.6756    128.421      0.099      0.921    -240.129     265.481
# C(month)[T.7L]     -32.5576    130.785     -0.249      0.804    -290.017     224.901
# C(month)[T.8L]     -40.3551    124.837     -0.323      0.747    -286.104     205.394
# C(month)[T.9L]     -34.0062    124.033     -0.274      0.784    -278.174     210.161
# C(month)[T.10L]    147.0944    118.021      1.246      0.214     -85.237     379.426
# C(month)[T.11L]   -171.3521    102.448     -1.673      0.096    -373.029      30.324
# C(month)[T.12L]     87.9525     93.503      0.941      0.348     -96.114     272.019
# CDH2                 0.0037      0.001      5.467      0.000       0.002       0.005
# HDH2                -0.0031      0.001     -6.150      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                       69.336   Durbin-Watson:                   1.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              161.879
# Skew:                          -1.141   Prob(JB):                     7.05e-36
# Kurtosis:                       5.846   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Savings

# %%
#rates = {'chw':0.056, 'steam':0.0157, 'elec':0.030} #kBTU prices for 2016(?)
#commodity = 'chw'

print("Savings = $" +str(round(mod.postCumsum * mod.params.commodityRate,1)))
mod.savings_plot(yaxis='dollars')
# Out:
# Savings = $754.9
